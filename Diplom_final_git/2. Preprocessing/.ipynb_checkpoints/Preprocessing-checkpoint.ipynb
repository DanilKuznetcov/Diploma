# %%
import numpy as np
import pandas as pd
import re
import warnings
warnings.filterwarnings('ignore')

import nltk
from nltk.corpus import stopwords  
from nltk import word_tokenize 
from nltk.stem import WordNetLemmatizer  

import matplotlib.pyplot as plt

from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# # Get data

# %%
data=pd.read_csv(r'крипта_2022-01-01 00:00:00-2022-01-02 00:00:00.csv', index_col=False)
data = data.drop(columns=['Unnamed: 0'])
data = data.rename(columns={'text': 'posts'})
data
# Out:
#                    date        id   owner_id    from_id  \
# 0   2022-01-01 00:01:01     52584 -201880129 -201880129
# 1   2022-01-01 08:23:59      8717  337679425  337679425
# 2   2022-01-01 07:30:00   1319396  -29231851  -29231851
# 3   2022-01-01 11:41:26      4029   77162208   77162208
# 4   2022-01-01 11:01:00    673154  -46730819  -46730819
# 5   2022-01-01 10:15:00    740351  -27680436  -27680436
# 6   2022-01-01 10:09:09       481 -164878976 -164878976
# 7   2022-01-01 10:08:19      6232 -105162659 -105162659
# 8   2022-01-01 13:54:57      1854   35127141   35127141
# 9   2022-01-01 13:47:57     14990 -192611461 -192611461
# 10  2022-01-01 13:30:00     72802 -140880848 -140880848
# 11  2022-01-01 12:51:02    125953 -110242131 -110242131
# 12  2022-01-01 12:18:10      1761  227734678  227734678
# 13  2022-01-01 15:23:28    247634  373283284  373283284
# 14  2022-01-01 20:09:32     72819 -140880848 -140880848
# 15  2022-01-01 19:58:00     13905   10481711   10481711
# 16  2022-01-01 19:30:00  10223307  -25232578  -25232578
# 17  2022-01-01 19:29:05       521  631741005  631741005
# 18  2022-01-01 19:17:50      9180 -113798035 -113798035
# 19  2022-01-01 19:00:00     11411 -180257925 -180257925
# 20  2022-01-01 19:00:00       124 -207053421 -207053421
# 21  2022-01-01 18:30:00     13475   -4994479   -4994479
# 22  2022-01-01 18:00:20     38175  -93019596  -93019596
# 23  2022-01-01 23:56:42     41403 -159867640 -159867640
# 24  2022-01-01 23:54:03      1451 -181263819 -181263819
# 25  2022-01-01 23:54:03      1452 -181263819 -181263819
# 26  2022-01-01 23:04:31       759  533037911  533037911
# 27  2022-01-01 22:51:05      2744 -204271201 -204271201
#
#                                                 posts  comments  likes  \
# 0   Дорогие инвесторы и трейдеры, вот и наступил 2...        16    195
# 1   💰👍🏻 Не знаете чем себя занять? \nПопробуйте ра...         0      7
# 2   ОЗЗИ ОСБОРН ПРОДАЕТ ЛЕТУЧИХ МЫШЕЙ В ФОРМЕ NFT\...         2     23
# 3   Бац и мы в 2️⃣0️⃣2️⃣2️⃣❗️\n\n🔥Мои краткие итог...         4     26
# 4   ОЗЗИ ОСБОРН ПРОДАЕТ ЛЕТУЧИХ МЫШЕЙ В ФОРМЕ NFT\...         1     18
# 5                                 А вы имеете крипту?         1     35
# 6   СТЕЙКИНГ КРИПТОВАЛЮТ\n\nЧто такое стейкинг кри...         0      3
# 7   Денис Борисов - Где мы. Полный прогноз на 2022...         0     20
# 8   31 декабря все подводили итоги уходящего 2021 ...         1     15
# 9   Как сохранить документ в данном формате (sgn)....        22     18
# 10  Почему децентрализация — это единственное важн...         4     87
# 11  ПРОЕКТ ПО ИСЧЕЗНОВЕНИЮ ЖЕНЩИН \n \nЗдравствуйт...         8     29
# 12  Былинный богатырь, герой русских сказок и свят...         1     10
# 13  Форум https://accederz.tech запустил конкурс н...         7     16
# 14  Общий объём стейблкоинов в нише цифровых актив...         5     18
# 15  Ян Бедерман (Россия) и Беркант Чакыджи (Турция...         0      1
# 16  Банк России продолжает давление на индустрию к...        14     23
# 17  🔺Если ты кит в мире криптовалюты или хочешь ра...         0      4
# 18  🎅🏻Дорогие друзья! Сообщество КриптоReLaX поздр...         2      9
# 19  📚 Бесплатный КУРС ПО КРИПТЕ от Гриза\nТо, собс...         9     75
# 20  🔝CRYPTO FUTURE 2022🔝 \nНовый год – новая конфе...         0      2
# 21  2 ЯНВАРЯ МЫ ПРОСЛАВЛЯЕМ ОДНОГО ИЗ САМЫХ ЛЮБИМЫ...         2    417
# 22  ► Власти Южной Кореи просят магазины приложени...         0      6
# 23  📢 Топ новости за день 📢\n \n💡Топ-5 токенов мет...         7     10
# 24  Друзья , сегодня 1 день 2022 года и совсем ско...         0      8
# 25  Друзья , сегодня 1 день 2022 года и совсем ско...         0      7
# 26  Всех с наступившим Новым 2022 Годом!!!!! Решил...         2     33
# 27  Hello World! Че спим? Отдыхаешь после Нового г...        10     84
#
#     reposts  views
# 0        13  12860
# 1         0     27
# 2        12  10046
# 3         0    668
# 4        19   6139
# 5         7   9807
# 6         5     97
# 7         8    951
# 8         0    287
# 9        13   3577
# 10       34   7844
# 11       49   5829
# 12        0    116
# 13        6   4480
# 14        2   3156
# 15        0    127
# 16       24  17436
# 17        0     59
# 18        2    207
# 19       73   4518
# 20        0    104
# 21       47   8181
# 22        2    744
# 23        2   2713
# 24        0    153
# 25        0    148
# 26       16   1385
# 27      181   9457

# %% [markdown]
# # Filter for zero-impact news (likes > 0 and not epmty)

# %%
not_empty_flags = [len(post) > 0 for post in data.posts]
len(not_empty_flags)
data = data[not_empty_flags & data.likes > 0]
data
# Out:
#                    date        id   owner_id    from_id  \
# 0   2022-01-01 00:01:01     52584 -201880129 -201880129
# 1   2022-01-01 08:23:59      8717  337679425  337679425
# 2   2022-01-01 07:30:00   1319396  -29231851  -29231851
# 5   2022-01-01 10:15:00    740351  -27680436  -27680436
# 6   2022-01-01 10:09:09       481 -164878976 -164878976
# 8   2022-01-01 13:54:57      1854   35127141   35127141
# 10  2022-01-01 13:30:00     72802 -140880848 -140880848
# 11  2022-01-01 12:51:02    125953 -110242131 -110242131
# 15  2022-01-01 19:58:00     13905   10481711   10481711
# 16  2022-01-01 19:30:00  10223307  -25232578  -25232578
# 18  2022-01-01 19:17:50      9180 -113798035 -113798035
# 19  2022-01-01 19:00:00     11411 -180257925 -180257925
# 21  2022-01-01 18:30:00     13475   -4994479   -4994479
# 25  2022-01-01 23:54:03      1452 -181263819 -181263819
# 26  2022-01-01 23:04:31       759  533037911  533037911
#
#                                                 posts  comments  likes  \
# 0   Дорогие инвесторы и трейдеры, вот и наступил 2...        16    195
# 1   💰👍🏻 Не знаете чем себя занять? \nПопробуйте ра...         0      7
# 2   ОЗЗИ ОСБОРН ПРОДАЕТ ЛЕТУЧИХ МЫШЕЙ В ФОРМЕ NFT\...         2     23
# 5                                 А вы имеете крипту?         1     35
# 6   СТЕЙКИНГ КРИПТОВАЛЮТ\n\nЧто такое стейкинг кри...         0      3
# 8   31 декабря все подводили итоги уходящего 2021 ...         1     15
# 10  Почему децентрализация — это единственное важн...         4     87
# 11  ПРОЕКТ ПО ИСЧЕЗНОВЕНИЮ ЖЕНЩИН \n \nЗдравствуйт...         8     29
# 15  Ян Бедерман (Россия) и Беркант Чакыджи (Турция...         0      1
# 16  Банк России продолжает давление на индустрию к...        14     23
# 18  🎅🏻Дорогие друзья! Сообщество КриптоReLaX поздр...         2      9
# 19  📚 Бесплатный КУРС ПО КРИПТЕ от Гриза\nТо, собс...         9     75
# 21  2 ЯНВАРЯ МЫ ПРОСЛАВЛЯЕМ ОДНОГО ИЗ САМЫХ ЛЮБИМЫ...         2    417
# 25  Друзья , сегодня 1 день 2022 года и совсем ско...         0      7
# 26  Всех с наступившим Новым 2022 Годом!!!!! Решил...         2     33
#
#     reposts  views
# 0        13  12860
# 1         0     27
# 2        12  10046
# 5         7   9807
# 6         5     97
# 8         0    287
# 10       34   7844
# 11       49   5829
# 15        0    127
# 16       24  17436
# 18        2    207
# 19       73   4518
# 21       47   8181
# 25        0    148
# 26       16   1385

# %% [markdown]
# # Delete all links

# %%
data['posts'] = data['posts'].apply(lambda x: re.sub(r'http\S+', '', x, flags=re.MULTILINE))
data['posts'] = data['posts'].apply(lambda x: re.sub(r'\[id.+?\]', '', x, flags=re.MULTILINE))
data['posts'] = data['posts'].apply(lambda x: re.sub(r'\[club.+?\]', '', x, flags=re.MULTILINE))
data
#id234234 & club1231
# data.loc[100].posts
# x = data.loc[1172].posts
# re.sub(r'http\S+', '', x)
# vk.com/id406209191 Татьяна Шушерова
# Out:
#                       date        id   owner_id    from_id  \
# 2      2022-01-01 23:54:03      1452 -181263819 -181263819
# 5      2022-01-01 19:58:00     13905   10481711   10481711
# 6      2022-01-01 19:30:00  10223307  -25232578  -25232578
# 8      2022-01-01 19:17:50      9180 -113798035 -113798035
# 10     2022-01-01 19:00:00     11411 -180257925 -180257925
# ...                    ...       ...        ...        ...
# 41887  2022-12-31 09:38:08       555  740932401  740932401
# 41888  2022-12-31 09:36:08     10204      35615      35615
# 41893  2022-12-31 03:41:45      9153   17001639   17001639
# 41894  2022-12-31 00:31:00      5721   40489531   40489531
# 41895  2022-12-31 00:27:04      7108  172089416  172089416
#
#                                                    posts  comments  likes  \
# 2      Друзья , сегодня 1 день 2022 года и совсем ско...         0      7
# 5      Ян Бедерман (Россия) и Беркант Чакыджи (Турция...         0      1
# 6      Банк России продолжает давление на индустрию к...        14     23
# 8      🎅🏻Дорогие друзья! Сообщество КриптоReLaX поздр...         2      9
# 10     📚 Бесплатный КУРС ПО КРИПТЕ от Гриза\nТо, собс...         9     75
# ...                                                  ...       ...    ...
# 41887  Криптовалюта интегрируется в футбол\n\nНаприме...         0      1
# 41888  Удаленные ниши, которые будут качать в 2023м\n...        14     81
# 41893  ХОРОШИЙ ПОДАРОК К НОВОМУ ГОДУ🎅🎁\n\nОдин из сам...         0     67
# 41894  Хуяк и 35!\n\nЯ достаточно редко мелькаю в лен...         0     43
# 41895  Заканчивается 2022 год. \n🎄🎄🎄🎄🎄🎄🎄🎄🎄🎄\n\nСамым ...         8     65
#
#        reposts  views
# 2            0    148
# 5            0    127
# 6           24  17436
# 8            2    207
# 10          73   4515
# ...        ...    ...
# 41887        0      8
# 41888       14   4518
# 41893        3    164
# 41894        3    824
# 41895        0    662
#
# [23598 rows x 9 columns]

# %%
#тут есть дичь напимер тупо список имён. Нужно построить графики для comments	likes	reposts	views
#и задать пороги

# %% [markdown]
# # Delete texts without cyrilic

# %%
not_cyrilic_flags = [bool(re.search('[а-яА-Я]', post)) for post in data.posts]
len(not_cyrilic_flags)
# not_cyrilic_flags
data = data[not_cyrilic_flags]
data
# [bool(re.search('[а-яА-Я]', post) for post in data.posts)]
# Out:
#                       date        id   owner_id    from_id  \
# 2      2022-01-01 23:54:03      1452 -181263819 -181263819
# 5      2022-01-01 19:58:00     13905   10481711   10481711
# 6      2022-01-01 19:30:00  10223307  -25232578  -25232578
# 8      2022-01-01 19:17:50      9180 -113798035 -113798035
# 10     2022-01-01 19:00:00     11411 -180257925 -180257925
# ...                    ...       ...        ...        ...
# 41887  2022-12-31 09:38:08       555  740932401  740932401
# 41888  2022-12-31 09:36:08     10204      35615      35615
# 41893  2022-12-31 03:41:45      9153   17001639   17001639
# 41894  2022-12-31 00:31:00      5721   40489531   40489531
# 41895  2022-12-31 00:27:04      7108  172089416  172089416
#
#                                                    posts  comments  likes  \
# 2      Друзья , сегодня 1 день 2022 года и совсем ско...         0      7
# 5      Ян Бедерман (Россия) и Беркант Чакыджи (Турция...         0      1
# 6      Банк России продолжает давление на индустрию к...        14     23
# 8      🎅🏻Дорогие друзья! Сообщество КриптоReLaX поздр...         2      9
# 10     📚 Бесплатный КУРС ПО КРИПТЕ от Гриза\nТо, собс...         9     75
# ...                                                  ...       ...    ...
# 41887  Криптовалюта интегрируется в футбол\n\nНаприме...         0      1
# 41888  Удаленные ниши, которые будут качать в 2023м\n...        14     81
# 41893  ХОРОШИЙ ПОДАРОК К НОВОМУ ГОДУ🎅🎁\n\nОдин из сам...         0     67
# 41894  Хуяк и 35!\n\nЯ достаточно редко мелькаю в лен...         0     43
# 41895  Заканчивается 2022 год. \n🎄🎄🎄🎄🎄🎄🎄🎄🎄🎄\n\nСамым ...         8     65
#
#        reposts  views
# 2            0    148
# 5            0    127
# 6           24  17436
# 8            2    207
# 10          73   4515
# ...        ...    ...
# 41887        0      8
# 41888       14   4518
# 41893        3    164
# 41894        3    824
# 41895        0    662
#
# [23596 rows x 9 columns]

# %% [markdown]
# # Drop duplicates posts

# %%
#deleting duplicates taking into account only text of posts
data = data.loc[data['posts'].drop_duplicates().index]
data.reset_index(drop=True, inplace=True)
data
# Out:
#                       date        id   owner_id    from_id  \
# 0      2022-01-01 23:54:03      1452 -181263819 -181263819
# 1      2022-01-01 19:58:00     13905   10481711   10481711
# 2      2022-01-01 19:30:00  10223307  -25232578  -25232578
# 3      2022-01-01 19:17:50      9180 -113798035 -113798035
# 4      2022-01-01 19:00:00     11411 -180257925 -180257925
# ...                    ...       ...        ...        ...
# 17851  2022-12-31 09:40:36      5159   -1534863   -1534863
# 17852  2022-12-31 09:36:08     10204      35615      35615
# 17853  2022-12-31 03:41:45      9153   17001639   17001639
# 17854  2022-12-31 00:31:00      5721   40489531   40489531
# 17855  2022-12-31 00:27:04      7108  172089416  172089416
#
#                                                    posts  comments  likes  \
# 0      Друзья , сегодня 1 день 2022 года и совсем ско...         0      7
# 1      Ян Бедерман (Россия) и Беркант Чакыджи (Турция...         0      1
# 2      Банк России продолжает давление на индустрию к...        14     23
# 3      🎅🏻Дорогие друзья! Сообщество КриптоReLaX поздр...         2      9
# 4      📚 Бесплатный КУРС ПО КРИПТЕ от Гриза\nТо, собс...         9     75
# ...                                                  ...       ...    ...
# 17851  С новым 2023 годом, \nдорогие братья и сёстры!...         2     87
# 17852  Удаленные ниши, которые будут качать в 2023м\n...        14     81
# 17853  ХОРОШИЙ ПОДАРОК К НОВОМУ ГОДУ🎅🎁\n\nОдин из сам...         0     67
# 17854  Хуяк и 35!\n\nЯ достаточно редко мелькаю в лен...         0     43
# 17855  Заканчивается 2022 год. \n🎄🎄🎄🎄🎄🎄🎄🎄🎄🎄\n\nСамым ...         8     65
#
#        reposts  views
# 0            0    148
# 1            0    127
# 2           24  17436
# 3            2    207
# 4           73   4515
# ...        ...    ...
# 17851        5   1098
# 17852       14   4518
# 17853        3    164
# 17854        3    824
# 17855        0    662
#
# [17856 rows x 9 columns]

# %% [markdown]
# ### Checks for duplicates

# %%
# len(data['posts'].unique())
# pd.DataFrame({'dupl' : data.groupby( [ "posts"] ).size()}).reset_index().sort_values(by='dupl', ascending=False).head(5)
# data.sort_values(by='dupl', ascending=False)
# data

# %% [markdown]
# # Filter posts with big numbers of emojis

# %%
# print(data.loc[967].posts)
# print(data.loc[1434].posts)
# print(data.loc[1292].posts)

# %%
emoji_count = [len(re.findall(u'[\U0001f34a-\U0001f650]', x)) for x in data.posts]
data = data[[flag < 10 for flag in emoji_count]]
data.reset_index(drop=True, inplace=True)
data
# Out:
#                       date        id   owner_id    from_id  \
# 0      2022-01-01 23:54:03      1452 -181263819 -181263819
# 1      2022-01-01 19:58:00     13905   10481711   10481711
# 2      2022-01-01 19:30:00  10223307  -25232578  -25232578
# 3      2022-01-01 19:00:00     11411 -180257925 -180257925
# 4      2022-01-01 18:30:00     13475   -4994479   -4994479
# ...                    ...       ...        ...        ...
# 16732  2022-12-31 11:02:51      5457   23456424   23456424
# 16733  2022-12-31 09:40:36      5159   -1534863   -1534863
# 16734  2022-12-31 09:36:08     10204      35615      35615
# 16735  2022-12-31 03:41:45      9153   17001639   17001639
# 16736  2022-12-31 00:31:00      5721   40489531   40489531
#
#                                                    posts  comments  likes  \
# 0      Друзья , сегодня 1 день 2022 года и совсем ско...         0      7
# 1      Ян Бедерман (Россия) и Беркант Чакыджи (Турция...         0      1
# 2      Банк России продолжает давление на индустрию к...        14     23
# 3      📚 Бесплатный КУРС ПО КРИПТЕ от Гриза\nТо, собс...         9     75
# 4      2 ЯНВАРЯ МЫ ПРОСЛАВЛЯЕМ ОДНОГО ИЗ САМЫХ ЛЮБИМЫ...         2    417
# ...                                                  ...       ...    ...
# 16732  🔥 Ключевые тренды крипты в 2023.\n⠀\n2022 год ...         0     35
# 16733  С новым 2023 годом, \nдорогие братья и сёстры!...         2     87
# 16734  Удаленные ниши, которые будут качать в 2023м\n...        14     81
# 16735  ХОРОШИЙ ПОДАРОК К НОВОМУ ГОДУ🎅🎁\n\nОдин из сам...         0     67
# 16736  Хуяк и 35!\n\nЯ достаточно редко мелькаю в лен...         0     43
#
#        reposts  views
# 0            0    148
# 1            0    127
# 2           24  17436
# 3           73   4515
# 4           47   8177
# ...        ...    ...
# 16732        1    983
# 16733        5   1098
# 16734       14   4518
# 16735        3    164
# 16736        3    824
#
# [16737 rows x 9 columns]

# %%
# data["emoji"]= emoji_count
emoji_count.sort()
plt.plot(range(len(emoji_count)), emoji_count)

# %% [markdown]
# # Import StopWords and Packets

# %%
from nltk.corpus import stopwords
from pymystem3 import Mystem
from string import punctuation

nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package stopwords to /home/danil/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/danil/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/danil/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/danil/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
# female_names = """Анастасиа"""
# female_names = female_names.split()
# with open('female_names.txt', 'w') as file:
#     file.write('\n'.join(female_names))
# female_names

# %%
# # eng_stop_words=list(nltk.corpus.stopwords.words('russian'))
# # rus_stop_words=list(nltk.corpus.stopwords.words('english'))
# # stop_words = eng_stop_words + rus_stop_words

# with open('stop_words.txt', 'r') as file:
#     stop_words = file.read()
#     stop_words = stop_words.split()
    
# with open('female_names.txt', 'r') as file:
#     female_names = file.read()
#     female_names = female_names.split()
    
# with open('female_surnames.txt', 'r') as file:
#     female_surnames = file.read()
#     female_surnames = female_surnames.split()
    
# with open('male_names.txt', 'r') as file:
#     male_names = file.read()
#     male_names = male_names.split()
    
# with open('male_surnames.txt', 'r') as file:
#     male_surnames = file.read()
#     male_surnames = male_surnames.split()


# stop_words += female_names + female_surnames + male_names + male_surnames
# stop_words = set(stop_words)
# # len(stop_words)
# stop_words = [word.lower() for word in stop_words]
# stop_words
# with open('all_stop_words.txt', 'w') as file:
#     file.write('\n'.join(stop_words))

# %%
with open('all_stop_words.txt', 'r') as file:
    stop_words = file.read()
    stop_words = stop_words.split()

stop_words
len(stop_words)
# Out:
# 1506

# %%
print(data.loc[1654].posts)
# Out:
# 💥💥💥
# Канал «Блокчейн Hunter | Вакансии в крипто-индустрии» успешно добавлен в каталог.
# __________
# Блокчейн Hunter – это удобный мост между криптопроектами и специалистами в самых разных сферах, связанных с блокчейн-индустрией. Аналог народного hh, но исключительно для крипто комьюнити.
# __________
# Перейти на сайт:
# Перейти на канал:
# __________
# #работа@katalog_kanalov
# #работа #БлокчейнHunter #вакансии #найтиработу #Вакансиивкриптоиндустрии #свежиевакансии #лучшиевакансии

# %% [markdown]
# # Lemmatization

# %%
mystem = Mystem()

# %%
def preprocess_text(text):
    tokens = mystem.lemmatize(text.lower())
    tokens = [token for token in tokens if token not in stop_words\
              and token != " " \
              and token.strip() not in punctuation]
    
    text = " ".join(tokens)
    
    return text

# %%
x = 'криптой'
preprocess_text(x)
# Out:
# 'крипта'

# %%
data['cleaned_posts'] = data.posts.apply(preprocess_text)

# %%
print(data.loc[1].posts)
data
# Out:
# Ян Бедерман (Россия) и Беркант Чакыджи (Турция) в КЦ АртЭрия.
# Студия Ратнера. Специальный концерт для художников в клубе Арт'Эриа в крипте храма Свт. Николая Чудотворца на Трех горах. 18.04.2019.
#
# #музыка #творчество #фольклор #искусство #культура #этно #этника #Бедерман #Чакыджи #импровизация
#                       date        id   owner_id    from_id  \
# 0      2022-01-01 23:54:03      1452 -181263819 -181263819
# 1      2022-01-01 19:58:00     13905   10481711   10481711
# 2      2022-01-01 19:30:00  10223307  -25232578  -25232578
# 3      2022-01-01 19:00:00     11411 -180257925 -180257925
# 4      2022-01-01 18:30:00     13475   -4994479   -4994479
# ...                    ...       ...        ...        ...
# 16732  2022-12-31 11:02:51      5457   23456424   23456424
# 16733  2022-12-31 09:40:36      5159   -1534863   -1534863
# 16734  2022-12-31 09:36:08     10204      35615      35615
# 16735  2022-12-31 03:41:45      9153   17001639   17001639
# 16736  2022-12-31 00:31:00      5721   40489531   40489531
#
#                                                    posts  comments  likes  \
# 0      Друзья , сегодня 1 день 2022 года и совсем ско...         0      7
# 1      Ян Бедерман (Россия) и Беркант Чакыджи (Турция...         0      1
# 2      Банк России продолжает давление на индустрию к...        14     23
# 3      📚 Бесплатный КУРС ПО КРИПТЕ от Гриза\nТо, собс...         9     75
# 4      2 ЯНВАРЯ МЫ ПРОСЛАВЛЯЕМ ОДНОГО ИЗ САМЫХ ЛЮБИМЫ...         2    417
# ...                                                  ...       ...    ...
# 16732  🔥 Ключевые тренды крипты в 2023.\n⠀\n2022 год ...         0     35
# 16733  С новым 2023 годом, \nдорогие братья и сёстры!...         2     87
# 16734  Удаленные ниши, которые будут качать в 2023м\n...        14     81
# 16735  ХОРОШИЙ ПОДАРОК К НОВОМУ ГОДУ🎅🎁\n\nОдин из сам...         0     67
# 16736  Хуяк и 35!\n\nЯ достаточно редко мелькаю в лен...         0     43
#
#        reposts  views                                      cleaned_posts
# 0            0    148  друг 1 2022 скоро узнавать новость компания ai...
# 1            0    127  бедерман россия беркант чакыджи турция кц артэ...
# 2           24  17436  банк россия продолжать давление индустрия крип...
# 3           73   4515  📚 бесплатный курс крипта гриз собственно из-за...
# 4           47   8177  2 январь прославлять самый любимый святой покр...
# ...        ...    ...                                                ...
# 16732        1    983  🔥 ключевой тренд крипта 2023 ⠀ 2022 подходить ...
# 16733        5   1098  новый 2023 дорогой брат сестра пусть мирный до...
# 16734       14   4518  удаленный ниша качать 2023м решать поделиться ...
# 16735        3    164  хороший подарок новый 🎅 🎁 самый надежный мир а...
# 16736        3    824  хуяк 35 достаточно редко мелькать лента грех н...
#
# [16737 rows x 10 columns]

# %% [markdown]
# # Drop duplicates posts

# %%
#deleting duplicates taking into account only text of posts
data = data.loc[data['cleaned_posts'].drop_duplicates().index]
data.reset_index(drop=True, inplace=True)
data
# print(data.loc[2].posts, '\n')
# print(data.loc[2].cleaned_posts)
# Out:
#                       date        id   owner_id    from_id  \
# 0      2022-01-01 23:54:03      1452 -181263819 -181263819
# 1      2022-01-01 19:58:00     13905   10481711   10481711
# 2      2022-01-01 19:30:00  10223307  -25232578  -25232578
# 3      2022-01-01 19:00:00     11411 -180257925 -180257925
# 4      2022-01-01 18:30:00     13475   -4994479   -4994479
# ...                    ...       ...        ...        ...
# 16493  2022-12-31 11:02:51      5457   23456424   23456424
# 16494  2022-12-31 09:40:36      5159   -1534863   -1534863
# 16495  2022-12-31 09:36:08     10204      35615      35615
# 16496  2022-12-31 03:41:45      9153   17001639   17001639
# 16497  2022-12-31 00:31:00      5721   40489531   40489531
#
#                                                    posts  comments  likes  \
# 0      Друзья , сегодня 1 день 2022 года и совсем ско...         0      7
# 1      Ян Бедерман (Россия) и Беркант Чакыджи (Турция...         0      1
# 2      Банк России продолжает давление на индустрию к...        14     23
# 3      📚 Бесплатный КУРС ПО КРИПТЕ от Гриза\nТо, собс...         9     75
# 4      2 ЯНВАРЯ МЫ ПРОСЛАВЛЯЕМ ОДНОГО ИЗ САМЫХ ЛЮБИМЫ...         2    417
# ...                                                  ...       ...    ...
# 16493  🔥 Ключевые тренды крипты в 2023.\n⠀\n2022 год ...         0     35
# 16494  С новым 2023 годом, \nдорогие братья и сёстры!...         2     87
# 16495  Удаленные ниши, которые будут качать в 2023м\n...        14     81
# 16496  ХОРОШИЙ ПОДАРОК К НОВОМУ ГОДУ🎅🎁\n\nОдин из сам...         0     67
# 16497  Хуяк и 35!\n\nЯ достаточно редко мелькаю в лен...         0     43
#
#        reposts  views                                      cleaned_posts
# 0            0    148  друг 1 2022 скоро узнавать новость компания ai...
# 1            0    127  бедерман россия беркант чакыджи турция кц артэ...
# 2           24  17436  банк россия продолжать давление индустрия крип...
# 3           73   4515  📚 бесплатный курс крипта гриз собственно из-за...
# 4           47   8177  2 январь прославлять самый любимый святой покр...
# ...        ...    ...                                                ...
# 16493        1    983  🔥 ключевой тренд крипта 2023 ⠀ 2022 подходить ...
# 16494        5   1098  новый 2023 дорогой брат сестра пусть мирный до...
# 16495       14   4518  удаленный ниша качать 2023м решать поделиться ...
# 16496        3    164  хороший подарок новый 🎅 🎁 самый надежный мир а...
# 16497        3    824  хуяк 35 достаточно редко мелькать лента грех н...
#
# [16498 rows x 10 columns]

# %%
# data.to_csv('cleaned_data_03')

# %% [markdown]
# # Clean lemat

# %%
# def clean_text(headline):
#     le=WordNetLemmatizer()
#     word_tokens=word_tokenize(headline)
#     tokens=[le.lemmatize(w) for w in word_tokens if w not in stop_words and len(w)>2]
#     cleaned_text=" ".join(tokens)
# #     print(headline, '\n')
#     return cleaned_text

# %%
# data['headline_cleaned_text']=data['posts'].apply(clean_text)

# %%
# df = data
# df

# %%
# df.drop(['posts'],axis=1,inplace=True)
data.head()
# Out:
#                   date        id   owner_id    from_id  \
# 0  2022-01-01 23:54:03      1452 -181263819 -181263819
# 1  2022-01-01 19:58:00     13905   10481711   10481711
# 2  2022-01-01 19:30:00  10223307  -25232578  -25232578
# 3  2022-01-01 19:00:00     11411 -180257925 -180257925
# 4  2022-01-01 18:30:00     13475   -4994479   -4994479
#
#                                                posts  comments  likes  \
# 0  Друзья , сегодня 1 день 2022 года и совсем ско...         0      7
# 1  Ян Бедерман (Россия) и Беркант Чакыджи (Турция...         0      1
# 2  Банк России продолжает давление на индустрию к...        14     23
# 3  📚 Бесплатный КУРС ПО КРИПТЕ от Гриза\nТо, собс...         9     75
# 4  2 ЯНВАРЯ МЫ ПРОСЛАВЛЯЕМ ОДНОГО ИЗ САМЫХ ЛЮБИМЫ...         2    417
#
#    reposts  views                                      cleaned_posts
# 0        0    148  друг 1 2022 скоро узнавать новость компания ai...
# 1        0    127  бедерман россия беркант чакыджи турция кц артэ...
# 2       24  17436  банк россия продолжать давление индустрия крип...
# 3       73   4515  📚 бесплатный курс крипта гриз собственно из-за...
# 4       47   8177  2 январь прославлять самый любимый святой покр...

# %%
# texts = df.groupby('headline_cleaned_text')['headline_cleaned_text'].count().reset_index(name='len')
# texts.sort_values('len')

# %% [markdown]
# ## Vectorizing usung TfidfVectorizer

# %%
#max_features - MAX vocabulare for comment
#TF-IDF. Эта аббревиатура означает "term frequency — inverse document frequency"
#каждая строка соответствует документу
#каждый столбец соответствует слову
vect = TfidfVectorizer(stop_words=stop_words,max_features=100)
vect_text=vect.fit_transform(data['cleaned_posts'])

# %%
#список всех рассматриваемых слов (100 самых встречаемых)
vect.vocabulary_
# Out:
# {'друг': 31,
#  '2022': 3,
#  'новость': 57,
#  'компания': 43,
#  'крипто': 46,
#  'кошелек': 44,
#  'новый': 58,
#  'обучение': 59,
#  'россия': 75,
#  'крипта': 45,
#  'храм': 96,
#  'банк': 12,
#  'криптовалюта': 47,
#  'актив': 9,
#  'курс': 49,
#  'последний': 67,
#  'свой': 80,
#  'проект': 71,
#  'рассказывать': 74,
#  'создавать': 86,
#  'писать': 61,
#  'поэтому': 68,
#  'деньги': 28,
#  'понимать': 66,
#  'тема': 92,
#  'делать': 26,
#  'канал': 40,
#  'заработок': 34,
#  'самый': 79,
#  'святой': 81,
#  'хороший': 95,
#  'давать': 25,
#  '10': 1,
#  'выходить': 23,
#  'монета': 55,
#  'доллар': 29,
#  'часть': 99,
#  'становиться': 88,
#  'знать': 35,
#  'место': 52,
#  'мир': 54,
#  'говорить': 24,
#  '20': 2,
#  'большой': 18,
#  'инвестиция': 37,
#  'работа': 72,
#  'вопрос': 21,
#  'игра': 36,
#  'начинать': 56,
#  'токен': 93,
#  'сеть': 83,
#  'блокчейн': 17,
#  'сделать': 82,
#  'помощь': 65,
#  'биткоин': 15,
#  'возможность': 20,
#  'рынок': 78,
#  'nft': 7,
#  'полный': 63,
#  'купить': 48,
#  'получать': 64,
#  'финансовый': 94,
#  'рубль': 76,
#  '000': 0,
#  'система': 84,
#  'месяц': 53,
#  'цена': 97,
#  'дело': 27,
#  'акция': 10,
#  'доход': 30,
#  'средство': 87,
#  'майнинг': 51,
#  'блок': 16,
#  'инвестор': 38,
#  'биржа': 14,
#  'смочь': 85,
#  'зарабатывать': 33,
#  'работать': 73,
#  'бизнес': 13,
#  'продавать': 70,
#  'цифровой': 98,
#  'покупать': 62,
#  'binance': 4,
#  'сша': 91,
#  'прогноз': 69,
#  'любой': 50,
#  'страна': 89,
#  'онлайн': 60,
#  'выход': 22,
#  'команда': 42,
#  'валюта': 19,
#  'запрет': 32,
#  'bitcoin': 5,
#  'btc': 6,
#  'счет': 90,
#  'карта': 41,
#  'интернет': 39,
#  'рф': 77,
#  'арбитраж': 11,
#  'p2p': 8}

# %%
# df['headline_cleaned_text'][1]

# %%
print(vect_text.shape)
# print(vect_text)
# vect_text
# Out:
# (16498, 100)

# %%
#all stored values ~ 2042*100
vect_text.getnnz()
# Out:
# 221594

# %%
#inverse document frequency for every word
#лог(число всех документов / число документов со словом)
idf=vect.idf_
idf.shape
idf
# Out:
# array([3.42692025, 2.84932797, 3.1699026 , 2.9999538 , 3.43380733,
#        3.4590011 , 3.35925518, 3.06565735, 4.00541596, 3.21107851,
#        3.44352962, 3.98842526, 3.32272719, 3.08790198, 2.73308696,
#        2.93200641, 4.57982856, 3.17843143, 2.95829024, 3.19789151,
#        2.8758713 , 2.97824752, 4.19782494, 3.42144453, 3.16197234,
#        2.80193287, 2.85783866, 3.24998954, 2.33289407, 3.11065272,
#        3.17950267, 3.11617066, 4.3394432 , 2.58246985, 3.21052557,
#        2.9514409 , 3.61433367, 2.7804892 , 3.27738851, 3.30010318,
#        3.04016022, 3.47255821, 3.32272719, 2.84471613, 3.18272329,
#        1.38586929, 1.97119842, 2.13126272, 2.98263927, 3.05519103,
#        2.98616661, 3.3446099 , 3.14577977, 3.04202676, 2.64610416,
#        3.2006245 , 2.5124156 , 3.12831656, 2.29500904, 3.38524755,
#        3.67843079, 3.06757214, 3.31902348, 3.5753677 , 2.48287816,
#        3.35477518, 3.11365873, 3.24941466, 3.14889342, 3.94717014,
#        3.31288096, 2.74066014, 2.64547562, 2.74933624, 3.12831656,
#        3.12475874, 3.03134141, 3.77374097, 2.474105  , 2.42453368,
#        1.92996032, 4.28133557, 2.84280079, 3.38327451, 3.40990725,
#        3.18057506, 3.17789624, 3.16831151, 2.51489391, 3.15881776,
#        3.34650804, 3.61516183, 3.29107513, 3.33579927, 3.2000773 ,
#        2.7726095 , 4.24180474, 3.01529706, 3.52188731, 3.31779196])

# %% [markdown]
# # Applying LDA

# %%
from sklearn.decomposition import LatentDirichletAllocation
lda_model=LatentDirichletAllocation(n_components=10,learning_method='online',random_state=42,max_iter=1)

# %%
#Матрица распределения текстов по темам
lda_top=lda_model.fit_transform(vect_text)

# %%
lda_model.components_.shape
lda_top.shape
lda_top[0]
# Out:
# array([0.0272261 , 0.02722455, 0.02726951, 0.02723354, 0.02722563,
#        0.0272259 , 0.45649612, 0.02726564, 0.32560088, 0.02723213])

# %%
sum=0
for i in lda_top[0]:
  sum=sum+i
print(sum)
# Out:
# 1.0000000000000002

# %%
# composition of doc 0 for eg
print("Document 0: ")
for i,topic in enumerate(lda_top[0]):
  print("Topic ",i,": ",topic*100,"%")
# Out:
# Document 0:
# Topic  0 :  2.722610190976129 %
# Topic  1 :  2.7224553194246925 %
# Topic  2 :  2.726951382004092 %
# Topic  3 :  2.7233539145548056 %
# Topic  4 :  2.7225630263853504 %
# Topic  5 :  2.722589857225964 %
# Topic  6 :  45.649611861900595 %
# Topic  7 :  2.726563500744814 %
# Topic  8 :  32.56008811984619 %
# Topic  9 :  2.723212826937369 %

# %%
# most important words for each topic
vocab = vect.get_feature_names_out()

for i, comp in enumerate(lda_model.components_):
    vocab_comp = zip(vocab, comp)
    sorted_words = sorted(vocab_comp, key= lambda x:x[1], reverse=True)[:10]
    print("Topic "+str(i)+": ")
    for t in sorted_words:
        print(t[0],end=" ")
    print("\n")
# Out:
# Topic 0:
# крипта святой храм место свой становиться самый большой часть мир
#
# Topic 1:
# заработок интернет майнинг зарабатывать 000 крипта рубль канал деньги онлайн
#
# Topic 2:
# nft крипто игра друг новый проект мир канал 2022 крипта
#
# Topic 3:
# свой крипта деньги делать знать работать начинать самый новый работа
#
# Topic 4:
# россия рф страна криптовалюта цифровой майнинг крипта банк запрет валюта
#
# Topic 5:
# рынок актив криптовалюта инвестор крипта инвестиция акция доллар цена валюта
#
# Topic 6:
# биткоин криптовалюта btc bitcoin майнинг крипта 2022 binance прогноз новость
#
# Topic 7:
# кошелек карта помощь счет средство свой крипта биржа деньги система
#
# Topic 8:
# крипто компания рынок сша новый биржа финансовый крипта бизнес доход
#
# Topic 9:
# binance биржа токен криптовалюта арбитраж p2p проект блокчейн монета крипто

# %%
# composition of doc 0 for eg
print("Document 0: ")
for i,topic in enumerate(lda_top[1]):
  print("Topic ",i,": ",topic*100,"%")
# Out:
# Document 0:
# Topic  0 :  65.46765708180524 %
# Topic  1 :  3.8364457977738695 %
# Topic  2 :  3.836458993672504 %
# Topic  3 :  3.8365799956551094 %
# Topic  4 :  3.8401373881378507 %
# Topic  5 :  3.8366279714653153 %
# Topic  6 :  3.8364471782311913 %
# Topic  7 :  3.8367487079769362 %
# Topic  8 :  3.836456524908096 %
# Topic  9 :  3.8364403603738877 %

# %%
# df = df.reset_index(drop=True)
# df[500]
# df

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
# Generate a word cloud image for given topic
def draw_word_cloud(index):
  imp_words_topic=""
  comp=lda_model.components_[index]
  vocab_comp = zip(vocab, comp)
  sorted_words = sorted(vocab_comp, key= lambda x:x[1], reverse=True)[:50]
  for word in sorted_words:
    imp_words_topic=imp_words_topic+" "+word[0]

  wordcloud = WordCloud(width=600, height=400).generate(imp_words_topic)
  plt.figure( figsize=(5,5))
  plt.imshow(wordcloud)
  plt.axis("off")
  plt.tight_layout()
  plt.show()

# %%
# topic 0
draw_word_cloud(0)

# %%
#plotting tools
import pyLDAvis
import pyLDAvis.gensim

# %%
lda = lda_model
corpus_lda = data['posts']
dictionary = list(vect.vocabulary_.keys())
len(corpus_lda)
corpus_lda
# Out:
# 0        Друзья , сегодня 1 день 2022 года и совсем ско...
# 1        Ян Бедерман (Россия) и Беркант Чакыджи (Турция...
# 2        Банк России продолжает давление на индустрию к...
# 3        📚 Бесплатный КУРС ПО КРИПТЕ от Гриза\nТо, собс...
# 4        2 ЯНВАРЯ МЫ ПРОСЛАВЛЯЕМ ОДНОГО ИЗ САМЫХ ЛЮБИМЫ...
#                                ...
# 16493    🔥 Ключевые тренды крипты в 2023.\n⠀\n2022 год ...
# 16494    С новым 2023 годом, \nдорогие братья и сёстры!...
# 16495    Удаленные ниши, которые будут качать в 2023м\n...
# 16496    ХОРОШИЙ ПОДАРОК К НОВОМУ ГОДУ🎅🎁\n\nОдин из сам...
# 16497    Хуяк и 35!\n\nЯ достаточно редко мелькаю в лен...
# Name: posts, Length: 16498, dtype: object

# %%
pyLDAvis.enable_notebook()

panel = pyLDAvis.gensim.prepare(lda, corpus_lda, dictionary, mds='tsne')
panel
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 3
#       1 pyLDAvis.enable_notebook()
# ----> 3 panel = pyLDAvis.gensim.prepare(lda, corpus_lda, dictionary, mds='tsne')
#       4 panel
#
# File ~/.local/lib/python3.10/site-packages/pyLDAvis/gensim.py:122, in prepare(topic_model, corpus, dictionary, doc_topic_dist, **kwargs)
#      77 def prepare(topic_model, corpus, dictionary, doc_topic_dist=None, **kwargs):
#      78     """Transforms the Gensim TopicModel and related corpus and dictionary into
#      79     the data structures needed for the visualization.
#      80
#    (...)
#     120     See `pyLDAvis.prepare` for **kwargs.
#     121     """
# --> 122     opts = fp.merge(_extract_data(topic_model, corpus, dictionary, doc_topic_dist), kwargs)
#     123     return vis_prepare(**opts)
#
# File ~/.local/lib/python3.10/site-packages/pyLDAvis/gensim.py:17, in _extract_data(topic_model, corpus, dictionary, doc_topic_dists)
#      14 import gensim
#      16 if not gensim.matutils.ismatrix(corpus):
# ---> 17     corpus_csc = gensim.matutils.corpus2csc(corpus, num_terms=len(dictionary))
#      18 else:
#      19     corpus_csc = corpus
#
# File ~/.local/lib/python3.10/site-packages/gensim/matutils.py:152, in corpus2csc(corpus, num_terms, dtype, num_docs, num_nnz, printprogress)
#     149     logger.info("PROGRESS: at document #%i", docno)
#     151 # zip(*doc) transforms doc to (token_indices, token_counts]
# --> 152 doc_indices, doc_data = zip(*doc) if doc else ([], [])
#     153 indices.extend(doc_indices)
#     154 data.extend(doc_data)
#
# ValueError: not enough values to unpack (expected 2, got 1)
