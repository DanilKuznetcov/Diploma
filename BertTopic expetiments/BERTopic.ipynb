# %%
import pandas as pd

# %%
from bertopic import BERTopic
from sklearn.datasets import fetch_20newsgroups

# docs = fetch_20newsgroups(subset='all',  remove=('headers', 'footers', 'quotes'))['data']

# %%
data = pd.read_csv('cleaned_data.csv')
data
docs = list(data.posts)
data
# Out:
#      Unnamed: 0                 date      id   owner_id    from_id  \
# 0             0  2022-12-13 00:06:03   46312 -172214536 -172214536
# 1             1  2022-12-13 06:18:13    5772 -163574913 -163574913
# 2             2  2022-12-13 08:30:56    1057 -164878976 -164878976
# 3             3  2022-12-13 09:06:31      14 -217663775 -217663775
# 4             4  2022-12-13 10:17:48    5776 -163574913 -163574913
# ..          ...                  ...     ...        ...        ...
# 447         447  2022-12-13 22:06:10     307 -212345346 -212345346
# 448         448  2022-12-13 22:00:01  488569 -145253784 -145253784
# 449         449  2022-12-13 23:53:01     122  746325268  746325268
# 450         450  2022-12-13 23:21:57    4887  284397361  284397361
# 451         451  2022-12-13 23:02:42     185  729860429  729860429
#
#                                                  posts  comments  likes  \
# 0    эфир радиостанция 12.12 2022 23 00 ≈ 00 мина  ...         0      1
# 1    добрый утро tronics ☕ ️ \n hе забывать посмотр...         0      1
# 2    crypto bot представлять crypto pay 💱 crypto pa...         0      3
# 3    crypto news заработок размещение микро новость...         0      1
# 4    📢 прошлый неделя bittorrent ✅ btt получать бол...         0      1
# ..                                                 ...       ...    ...
# 447  хороший криптовалюта 13 декабрь данные coingec...         0      1
# 448  manyawelt mw обсера  —  правый либерал правосл...        23      3
# 449  камчатский край оканчивать расследование уголо...         0      3
# 450  statista количество криптовалюта уменьшаться 1...         0      1
# 451  дело добровольный депутат кардинальный передел...         0      1
#
#      reposts   views
# 0          0   136.0
# 1          0    94.0
# 2          5   215.0
# 3          0     2.0
# 4          0    76.0
# ..       ...     ...
# 447        0    22.0
# 448        3  1640.0
# 449        0   102.0
# 450        1    66.0
# 451        0     6.0
#
# [452 rows x 10 columns]

# %%
# topic_model = BERTopic()
# topics, probs = topic_model.fit_transform(docs)
# topic_model.save("crypto_model")

# %%
topic_model = BERTopic.load("my_model")

# %%
# docs[989]

# %%
topic_model.get_topic_info()
# Out:
#      Topic  Count                                              Name
# 0       -1   6756                                  -1_to_the_of_and
# 1        0   1810                              0_game_team_games_he
# 2        1    616                     1_key_clipper_chip_encryption
# 3        2    526                       2_idjits_ites_cheek_dancing
# 4        3    482                        3_israel_israeli_jews_arab
# ..     ...    ...                                               ...
# 218    217     10                       217_wires_turbo_desc_switch
# 219    218     10             218_image_plplot_processing_available
# 220    219     10                            219_ide_bus_buffer_mbs
# 221    220     10  220_manhattan_bobbeviceicotekcom_beauchaine_sank
# 222    221     10                      221_icon_click_icons_manager
#
# [223 rows x 3 columns]

# %%
topic_model.get_topic(2)
# Out:
# [('idjits', 0.637890960365614),
#  ('ites', 0.5454853159506012),
#  ('cheek', 0.5081915734837041),
#  ('dancing', 0.441678862440895),
#  ('yep', 0.3773173948374581),
#  ('huh', 0.33905739243536875),
#  ('ken', 0.3129785628784205),
#  ('forget', 0.25836822262276277),
#  ('why', 0.23132109075968607),
#  ('lets', 0.2087571711588597)]

# %%
topic_model.get_document_info(docs)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 topic_model.get_document_info(docs)
#
# File ~/.local/lib/python3.10/site-packages/bertopic/_bertopic.py:1471, in BERTopic.get_document_info(self, docs, df, metadata)
#    1469     document_info["Topic"] = self.topics_
#    1470 else:
# -> 1471     document_info = pd.DataFrame({"Document": docs, "Topic": self.topics_})
#    1473 # Add topic info through `.get_topic_info()`
#    1474 topic_info = self.get_topic_info().drop("Count", axis=1)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:663, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     657     mgr = self._init_mgr(
#     658         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     659     )
#     661 elif isinstance(data, dict):
#     662     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 663     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     664 elif isinstance(data, ma.MaskedArray):
#     665     import numpy.ma.mrecords as mrecords
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/construction.py:493, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     489     else:
#     490         # dtype check to exclude e.g. range objects, scalars
#     491         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 493 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/construction.py:118, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     115 if verify_integrity:
#     116     # figure out the index, if necessary
#     117     if index is None:
# --> 118         index = _extract_index(arrays)
#     119     else:
#     120         index = ensure_index(index)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/construction.py:666, in _extract_index(data)
#     664 lengths = list(set(raw_lengths))
#     665 if len(lengths) > 1:
# --> 666     raise ValueError("All arrays must be of the same length")
#     668 if have_dicts:
#     669     raise ValueError(
#     670         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     671     )
#
# ValueError: All arrays must be of the same length

# %%
df = topic_model.get_document_info(docs)
df.sort_values(by=['Representative_document'])

# %%
topic_model.topic_representations_
